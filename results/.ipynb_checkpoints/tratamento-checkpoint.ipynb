# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter
import random
import sqlite3
import numpy as np
# Out:
# C:\Users\pcozz\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Conectar ao banco de dados SQLite
conn = sqlite3.connect('../database.db')

# Consulta SQL para selecionar os dados da tabela desejada
query = "SELECT * FROM vaga;"

# Ler os dados do banco de dados SQLite para um DataFrame do Pandas
dados = pd.read_sql_query(query, conn)

# Fechar a conexão com o banco de dados
conn.close()
# dados = pd.read_csv("linkedin_jobs.csv")

# %%
dados = dados.reset_index(drop=True)
dados.set_index('id', inplace=True)

# %%
dados.describe()
# Out:
#                 title       location time_opened  \
# count            2001           2001        2001
# unique            672             35          44
# top     Desenvolvedor  São Paulo, SP    Há 1 mês
# freq              165           1193         338
#
#                                                      link  \
# count                                                2001
# unique                                               2001
# top     https://br.linkedin.com/jobs/view/desenvolvedo...
# freq                                                    1
#
#                                     applications experience_level  \
# count                                       1243             1759
# unique                                         2                7
# top     Seja um dos 25 primeiros a se candidatar       Assistente
# freq                                        1045              890
#
#               job_type                                   role  \
# count             1759                                   1759
# unique               5                                     36
# top     Tempo integral  Engenharia e Tecnologia da informação
# freq              1687                                   1191
#
#                                                   sectors  \
# count                                                1756
# unique                                                 91
# top     Atividades dos serviços de tecnologia da infor...
# freq                                                  453
#
#                                               description
# count                                                1757
# unique                                                853
# top     DESCRIÇÃOProfissional irá fazer parte do nosso...
# freq                                                   12

# %%
dados_tec=dados[dados['title'].str.contains("QA|Implantação|Programação|Desenvolvedor|Programador|Developer|Analista|Desenvolvimento|Engenheiro|Software|Estágio|Tecnologicas|Tecnologia|Computação|Tech|stack|Dev|Data|Desenvolver|TI",case=False, regex=True)]

# %%
dados_tec
# Out:
#                                                   title  \
# id
# 1                                   Desenvolvedor MYSQL
# 2                                         Desenvolvedor
# 3                            Desenvolvedor(a) Front-End
# 4                           Desenvolvedor full stack jr
# 5                                       Programador Web
# ...                                                 ...
# 1996    Analista e Desenvolvedor Progress Totvs Datasul
# 1997  DESENVOLVEDOR(A) BACK END - PLENO - Back-End |...
# 1998                          Desenvolvedor Java Sênior
# 1999                    Programador Golang Pleno/Sênior
# 2001                     Analista Programador C# Sênior
#
#                     location  time_opened  \
# id
# 1     Greater São Paulo Area   Há 3 meses
# 2     Greater São Paulo Area  Há 1 semana
# 3              São Paulo, SP   Há 2 meses
# 4     Greater São Paulo Area     Há 1 mês
# 5     Greater São Paulo Area   Há 2 meses
# ...                      ...          ...
# 1996           São Paulo, SP    Há 3 dias
# 1997           São Paulo, SP    Há 2 dias
# 1998           São Paulo, SP  Há 1 semana
# 1999           São Paulo, SP  Há 1 semana
# 2001              Osasco, SP   Há 2 meses
#
#                                                    link  \
# id
# 1     https://br.linkedin.com/jobs/view/desenvolvedo...
# 2     https://br.linkedin.com/jobs/view/desenvolvedo...
# 3     https://br.linkedin.com/jobs/view/desenvolvedo...
# 4     https://br.linkedin.com/jobs/view/desenvolvedo...
# 5     https://br.linkedin.com/jobs/view/programador-...
# ...                                                 ...
# 1996  https://br.linkedin.com/jobs/view/analista-e-d...
# 1997  https://br.linkedin.com/jobs/view/desenvolvedo...
# 1998  https://br.linkedin.com/jobs/view/desenvolvedo...
# 1999  https://br.linkedin.com/jobs/view/programador-...
# 2001  https://br.linkedin.com/jobs/view/analista-pro...
#
#                                   applications experience_level  \
# id
# 1     Seja um dos 25 primeiros a se candidatar       Assistente
# 2     Seja um dos 25 primeiros a se candidatar       Assistente
# 3     Seja um dos 25 primeiros a se candidatar       Assistente
# 4     Seja um dos 25 primeiros a se candidatar       Assistente
# 5     Seja um dos 25 primeiros a se candidatar       Assistente
# ...                                        ...              ...
# 1996  Seja um dos 25 primeiros a se candidatar    Não aplicável
# 1997  Seja um dos 25 primeiros a se candidatar     Pleno-sênior
# 1998                                      None             None
# 1999                                      None             None
# 2001                                      None             None
#
#             job_type                                   role  \
# id
# 1     Tempo integral  Engenharia e Tecnologia da informação
# 2     Tempo integral  Engenharia e Tecnologia da informação
# 3     Tempo integral  Engenharia e Tecnologia da informação
# 4           Contrato               Tecnologia da informação
# 5     Tempo integral  Engenharia e Tecnologia da informação
# ...              ...                                    ...
# 1996  Tempo integral  Engenharia e Tecnologia da informação
# 1997  Tempo integral  Engenharia e Tecnologia da informação
# 1998            None                                   None
# 1999            None                                   None
# 2001            None                                   None
#
#                                                 sectors  \
# id
# 1           Sociedades de fomento mercantil - factoring
# 2                     Tecnologia, Informação e Internet
# 3                     Tecnologia, Informação e Internet
# 4                        Serviços de gestão estratégica
# 5              Produtos de software de computação móvel
# ...                                                 ...
# 1996  Atividades dos serviços de tecnologia da infor...
# 1997                        Desenvolvimento de software
# 1998                                               None
# 1999                                               None
# 2001                                               None
#
#                                             description
# id
# 1     Manipular arquivos do servidor web. Criar scri...
# 2     Vagas para os times de tecnologia e desenvolvi...
# 3                                                  None
# 4     Olá Dev.Estamos com posições em andamento aqui...
# 5     Projetar, construir e otimizar interfaces dos ...
# ...                                                 ...
# 1996  Oportunidade de vagas como analista desenvolve...
# 1997  HabilidadesLaravel, PHP, ReactJS, Vue.jsO que ...
# 1998                                               None
# 1999                                               None
# 2001                                               None
#
# [1985 rows x 10 columns]

# %%
dados_tec[dados_tec.duplicated()]
# Out:
# Empty DataFrame
# Columns: [title, location, time_opened, link, applications, experience_level, job_type, role, sectors, description]
# Index: []

# %%
dados_tec.isnull().sum()
# Out:
# title                 0
# location              0
# time_opened           0
# link                  0
# applications        755
# experience_level    241
# job_type            241
# role                241
# sectors             244
# description         243
# dtype: int64

# %%
dados_tec.applications.value_counts()
# Out:
# applications
# Seja um dos 25 primeiros a se candidatar    1034
# Mais de 200 candidaturas                     196
# Name: count, dtype: int64

# %%
dados_tec.applications.fillna('Hidden',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\4249411417.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.applications.fillna('Hidden',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\4249411417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.applications.fillna('Hidden',inplace=True)

# %%
dados_tec.loc[dados['applications']=='Seja um dos 25 primeiros a se candidatar','applications']="<=25"
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\201576818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.loc[dados['applications']=='Seja um dos 25 primeiros a se candidatar','applications']="<=25"

# %%
dados_tec.loc[dados['applications']=='Mais de 200 candidaturas','applications']=">25"
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\4115778453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.loc[dados['applications']=='Mais de 200 candidaturas','applications']=">25"

# %%
dados_tec.applications.value_counts()
# Out:
# applications
# <=25      1034
# Hidden     755
# >25        196
# Name: count, dtype: int64

# %%
dados_tec.isnull().sum()
# Out:
# title                 0
# location              0
# time_opened           0
# link                  0
# applications          0
# experience_level    241
# job_type            241
# role                241
# sectors             244
# description         243
# dtype: int64

# %%
dados_tec.experience_level.value_counts()
# Out:
# experience_level
# Assistente       880
# Pleno-sênior     499
# Não aplicável    354
# Executivo          5
# Diretor            4
# Estágio            1
# Júnior             1
# Name: count, dtype: int64

# %%
dados_tec.experience_level.fillna('Assistente',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\1583094988.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.experience_level.fillna('Assistente',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\1583094988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.experience_level.fillna('Assistente',inplace=True)

# %%
dados_tec.experience_level.value_counts()
# Out:
# experience_level
# Assistente       1121
# Pleno-sênior      499
# Não aplicável     354
# Executivo           5
# Diretor             4
# Estágio             1
# Júnior              1
# Name: count, dtype: int64

# %%
dados_tec.job_type.value_counts()
# Out:
# job_type
# Tempo integral    1673
# Contrato            68
# Estágio              2
# Outro                1
# Name: count, dtype: int64

# %%
dados_tec.job_type.fillna('Tempo integral',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\3450007596.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.job_type.fillna('Tempo integral',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\3450007596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.job_type.fillna('Tempo integral',inplace=True)

# %%
dados_tec.role.value_counts()
# Out:
# role
# Engenharia e Tecnologia da informação                             1190
# Tecnologia da informação                                           272
# Desenvolvimento de negócios e Vendas                               125
# Outro                                                               78
# Engenharia                                                          11
# Recursos humanos                                                     9
# Analista                                                             7
# Gerenciamento e Manufatura                                           3
# Administração                                                        3
# Publicidade                                                          3
# Tecnologia da informação e Desenvolvimento de negócios               3
# Educação e Treinamento                                               3
# Gestão de produtos e Marketing                                       3
# Estratégia/Planejamento                                              3
# Financeiro, Tecnologia da informação e Consultoria                   3
# Financeiro                                                           3
# Design, Arte/Criação e Tecnologia da informação                      3
# Tecnologia da informação e Gestão de projetos                        2
# Provedor de assistência médica                                       2
# Educação superior                                                    2
# Pesquisa, Analista e Tecnologia da informação                        2
# Negócios em geral, Gerenciamento e Desenvolvimento de negócios       2
# Design                                                               1
# Tecnologia da informação, Marketing e Relações públicas              1
# Analista, Tecnologia da informação e Outro                           1
# Analista, Arte/Criação e Desenvolvimento de negócios                 1
# Atendimento ao Cliente, Design e Engenharia                          1
# Consultoria                                                          1
# Marketing, Relações públicas e Composição e revisão de textos        1
# Tecnologia da informação e Outro                                     1
# Tecnologia da informação, Analista e Estratégia/Planejamento         1
# Controle de qualidade                                                1
# Outro, Tecnologia da informação e Gerenciamento                      1
# Atividades dos serviços de tecnologia da informação                  1
# Name: count, dtype: int64

# %%
dados_tec.role.fillna('Engenharia e Tecnologia da informação',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\3605342044.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.role.fillna('Engenharia e Tecnologia da informação',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\3605342044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.role.fillna('Engenharia e Tecnologia da informação',inplace=True)

# %%
dados_tec.sectors.value_counts()
# Out:
# sectors
# Atividades dos serviços de tecnologia da informação                                                                                                              452
# Tecnologia, Informação e Internet                                                                                                                                201
# Fornecimento e gestão de recursos humanos                                                                                                                        187
# Segurança de redes e computadores                                                                                                                                116
# Recrutamento e seleção de pessoal                                                                                                                                 79
#                                                                                                                                                                 ...
# Lazer, viagens e turismo                                                                                                                                           1
# Desenvolvimento de programas                                                                                                                                       1
# Recursos renováveis e meio ambiente                                                                                                                                1
# Terceirização e offshoring                                                                                                                                         1
# Comércio de veículos motores e peças, Fabricação de peças e acessórios para veículos automotores e Fabricação de veículos automotores, reboques e carrocerias      1
# Name: count, Length: 90, dtype: int64

# %%
dados_tec.sectors.fillna('Atividades dos serviços de tecnologia da informação',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\2035285023.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.sectors.fillna('Atividades dos serviços de tecnologia da informação',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\2035285023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.sectors.fillna('Atividades dos serviços de tecnologia da informação',inplace=True)

# %%
dados_tec.description.fillna('Sem descrição',inplace=True)
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\2141726329.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_tec.description.fillna('Sem descrição',inplace=True)
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\2141726329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_tec.description.fillna('Sem descrição',inplace=True)

# %%
dados_tec
# Out:
#                                                   title  \
# id
# 1                                   Desenvolvedor MYSQL
# 2                                         Desenvolvedor
# 3                            Desenvolvedor(a) Front-End
# 4                           Desenvolvedor full stack jr
# 5                                       Programador Web
# ...                                                 ...
# 1996    Analista e Desenvolvedor Progress Totvs Datasul
# 1997  DESENVOLVEDOR(A) BACK END - PLENO - Back-End |...
# 1998                          Desenvolvedor Java Sênior
# 1999                    Programador Golang Pleno/Sênior
# 2001                     Analista Programador C# Sênior
#
#                     location  time_opened  \
# id
# 1     Greater São Paulo Area   Há 3 meses
# 2     Greater São Paulo Area  Há 1 semana
# 3              São Paulo, SP   Há 2 meses
# 4     Greater São Paulo Area     Há 1 mês
# 5     Greater São Paulo Area   Há 2 meses
# ...                      ...          ...
# 1996           São Paulo, SP    Há 3 dias
# 1997           São Paulo, SP    Há 2 dias
# 1998           São Paulo, SP  Há 1 semana
# 1999           São Paulo, SP  Há 1 semana
# 2001              Osasco, SP   Há 2 meses
#
#                                                    link applications  \
# id
# 1     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 2     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 3     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 4     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 5     https://br.linkedin.com/jobs/view/programador-...         <=25
# ...                                                 ...          ...
# 1996  https://br.linkedin.com/jobs/view/analista-e-d...         <=25
# 1997  https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 1998  https://br.linkedin.com/jobs/view/desenvolvedo...       Hidden
# 1999  https://br.linkedin.com/jobs/view/programador-...       Hidden
# 2001  https://br.linkedin.com/jobs/view/analista-pro...       Hidden
#
#      experience_level        job_type                                   role  \
# id
# 1          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 2          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 3          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 4          Assistente        Contrato               Tecnologia da informação
# 5          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# ...               ...             ...                                    ...
# 1996    Não aplicável  Tempo integral  Engenharia e Tecnologia da informação
# 1997     Pleno-sênior  Tempo integral  Engenharia e Tecnologia da informação
# 1998       Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 1999       Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 2001       Assistente  Tempo integral  Engenharia e Tecnologia da informação
#
#                                                 sectors  \
# id
# 1           Sociedades de fomento mercantil - factoring
# 2                     Tecnologia, Informação e Internet
# 3                     Tecnologia, Informação e Internet
# 4                        Serviços de gestão estratégica
# 5              Produtos de software de computação móvel
# ...                                                 ...
# 1996  Atividades dos serviços de tecnologia da infor...
# 1997                        Desenvolvimento de software
# 1998  Atividades dos serviços de tecnologia da infor...
# 1999  Atividades dos serviços de tecnologia da infor...
# 2001  Atividades dos serviços de tecnologia da infor...
#
#                                             description
# id
# 1     Manipular arquivos do servidor web. Criar scri...
# 2     Vagas para os times de tecnologia e desenvolvi...
# 3                                         Sem descrição
# 4     Olá Dev.Estamos com posições em andamento aqui...
# 5     Projetar, construir e otimizar interfaces dos ...
# ...                                                 ...
# 1996  Oportunidade de vagas como analista desenvolve...
# 1997  HabilidadesLaravel, PHP, ReactJS, Vue.jsO que ...
# 1998                                      Sem descrição
# 1999                                      Sem descrição
# 2001                                      Sem descrição
#
# [1985 rows x 10 columns]

# %%
dados_nao_nulos = dados_tec
dados_nao_nulos.isnull().sum()
# Out:
# title               0
# location            0
# time_opened         0
# link                0
# applications        0
# experience_level    0
# job_type            0
# role                0
# sectors             0
# description         0
# dtype: int64

# %%
regex_str = r'Excel|Windows|Linux|\\bC\\b|\\bC\+\+\\b|\bGIT|ASSEMBLY|GRAPHQL|DELPHI|PL/SQL|Node\.?JS|CSS|HTML|Wordpress|Angular(?:JS)?|Airflow|NOSQL|Spark|Power BI|Salesforce|DotNet|PASCAL|COBOL|ABAP|JAVASCRIPT|JAVA|SQL|Python|Angular|\.NET|AWS|GCP|Azure|Cloud|C#|Flutter|React|REACT\.JS|Ruby|Rails|Bootstrap|jQuery|Vue\.js|Express|Django|Spring|MVC|Android|Kotlin|GOLANG|\bGO\b|Swift|Objective-C|PHP|Laravel'

# %%
#Buscar tecnologia no titulo da vaga
def busca_tecnologia(title):
    tecnologia =[]
    matches=re.findall(regex_str, title,re.IGNORECASE)
    if matches:
        for match in matches:
            cleaned_match = match.upper().replace(" ", "").replace("-", "")
            tecnologia.append(cleaned_match)

        tecnologia = list(set(tecnologia))
        
        for i, item in enumerate(tecnologia):
            if item == "GOLANG":
                tecnologia[i] = "GO"
            elif item == "DOTNET" or item == "NET":
                tecnologia[i] = ".NET"
            elif item == "NODEJS":
                tecnologia[i] = "NODE.JS"
            elif item == "REACTJS":
                tecnologia[i] = "REACT"
            elif item == "REACT.JS":
                tecnologia[i] = "REACT"
#     
    else: 
        tecnologia= ["Não especificado"]
        
    return ', '.join(map(str, tecnologia))
    
#Buscar tecnologia no titulo da vaga
def busca_tecnologia_grafico(title):
    tecnologia =[]
    matches=re.findall(regex_str, title,re.IGNORECASE)
    if matches:
        for match in matches:
            cleaned_match = match.upper().replace(" ", "").replace("-", "")
            tecnologia.append(cleaned_match)

        tecnologia = list(set(tecnologia))
        
        for i, item in enumerate(tecnologia):
            if item == "GOLANG":
                tecnologia[i] = "GO"
            elif item == "DOTNET" or item == "NET":
                tecnologia[i] = ".NET"
            elif item == "NODEJS":
                tecnologia[i] = "NODE.JS"
#     
    else: 
        tecnologia = "Não especificado"
        
    return  tecnologia

# %%
dados_nao_nulos['temp'] = dados_nao_nulos['title'] +" "+ dados_nao_nulos['description']
dados_nao_nulos['requisitos'] = dados_nao_nulos.temp.apply(lambda x: busca_tecnologia(x))
dados_nao_nulos['lista'] = dados_nao_nulos.temp.apply(lambda x: busca_tecnologia_grafico(x))

dados_nao_nulos = dados_nao_nulos.drop(columns=['temp'])
# Out:
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\1252677813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_nao_nulos['temp'] = dados_nao_nulos['title'] +" "+ dados_nao_nulos['description']
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\1252677813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_nao_nulos['requisitos'] = dados_nao_nulos.temp.apply(lambda x: busca_tecnologia(x))
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\1252677813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_nao_nulos['lista'] = dados_nao_nulos.temp.apply(lambda x: busca_tecnologia_grafico(x))

# %%
dados_nao_nulos.requisitos.describe()
# Out:
# count                 1985
# unique                 587
# top       Não especificado
# freq                   267
# Name: requisitos, dtype: object

# %%
dados_nao_nulos.requisitos.value_counts()
# Out:
# requisitos
# Não especificado                                                                    267
# .NET                                                                                 74
# JAVA                                                                                 66
# EXCEL                                                                                28
# SQL                                                                                  22
#                                                                                    ...
# CLOUD                                                                                 1
# JAVA, SQL, JAVASCRIPT, SPRING, GIT, AWS, ANGULAR, HTML, CSS                           1
# CLOUD, JAVA, NODE.JS, NODE.JS, SPRING, AZURE, GIT, ANGULARJS, LINUX, PYTHON, AWS      1
# CLOUD, JAVA, SPRING, PL/SQL, AWS                                                      1
# LARAVEL, REACT, PHP, EXPRESS, VUE.JS                                                  1
# Name: count, Length: 587, dtype: int64

# %%
dados_nao_nulos.head(30)
# Out:
#                                                 title                location  \
# id
# 1                                 Desenvolvedor MYSQL  Greater São Paulo Area
# 2                                       Desenvolvedor  Greater São Paulo Area
# 3                          Desenvolvedor(a) Front-End           São Paulo, SP
# 4                         Desenvolvedor full stack jr  Greater São Paulo Area
# 5                                     Programador Web  Greater São Paulo Area
# 6                 Desenvolvedor Web (Brasil - Remoto)           São Paulo, SP
# 7                                  Back End Developer           São Paulo, SP
# 8                      DESENVOLVEDOR REACT JR (VIBRA)           São Paulo, SP
# 9                                       Desenvolvedor  Greater São Paulo Area
# 10        Desenvolvedor(a) Front-End Júnior (Angular)           São Paulo, SP
# 11                            DESENVOLVEDOR FRONT END                Mauá, SP
# 12  Banco de Talentos IOB (Profissional de desenvo...           São Paulo, SP
# 13                            Desenvolvedor Front-end           São Paulo, SP
# 14   Desenvolvedor(a) Python (Híbrido / São Paulo-SP)           São Paulo, SP
# 15           Desenvolvedor(a) Web (Banco de Talentos)           São Paulo, SP
# 16                          Desenvolvedor(a) Software           São Paulo, SP
# 17                    Desenvolvedor(a) Backend Junior           São Paulo, SP
# 18                      Desenvolvedor Backend Java Jr           São Paulo, SP
# 19                      Estágio de Desenvolvedor JAVA  Greater São Paulo Area
# 20                                      Desenvolvedor  Greater São Paulo Area
# 21                            Desenvolvedor Front End           São Paulo, SP
# 22                             Desenvolvedor Frontend           São Paulo, SP
# 23                 Desenvolvedor Java Junior (360667)           São Paulo, SP
# 24    Desenvolvedor(a) Frontend Junior | Vue | Brasil           São Paulo, SP
# 25                                Desenvolvedor MYSQL  Greater São Paulo Area
# 26                                      Desenvolvedor  Greater São Paulo Area
# 27                         Desenvolvedor(a) Front-End           São Paulo, SP
# 28                        Desenvolvedor full stack jr  Greater São Paulo Area
# 29                                    Programador Web  Greater São Paulo Area
# 30                Desenvolvedor Web (Brasil - Remoto)           São Paulo, SP
#
#      time_opened                                               link  \
# id
# 1     Há 3 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 2    Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 3     Há 2 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 4       Há 1 mês  https://br.linkedin.com/jobs/view/desenvolvedo...
# 5     Há 2 meses  https://br.linkedin.com/jobs/view/programador-...
# 6    Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 7   Há 2 semanas  https://br.linkedin.com/jobs/view/back-end-dev...
# 8    Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 9    Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 10    Há 2 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 11    Há 3 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 12    Há 8 meses  https://br.linkedin.com/jobs/view/banco-de-tal...
# 13  Há 3 semanas  https://br.linkedin.com/jobs/view/desenvolvedo...
# 14   Há 11 horas  https://br.linkedin.com/jobs/view/desenvolvedo...
# 15  Há 2 semanas  https://br.linkedin.com/jobs/view/desenvolvedo...
# 16    Há 2 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 17     Há 4 dias  https://br.linkedin.com/jobs/view/desenvolvedo...
# 18      Há 1 dia  https://br.linkedin.com/jobs/view/desenvolvedo...
# 19      Há 1 mês  https://br.linkedin.com/jobs/view/est%C3%A1gio...
# 20   Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 21  Há 3 semanas  https://br.linkedin.com/jobs/view/desenvolvedo...
# 22      Há 1 dia  https://br.linkedin.com/jobs/view/desenvolvedo...
# 23  Há 2 semanas  https://br.linkedin.com/jobs/view/desenvolvedo...
# 24      Há 1 dia  https://br.linkedin.com/jobs/view/desenvolvedo...
# 25    Há 3 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 26   Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
# 27    Há 2 meses  https://br.linkedin.com/jobs/view/desenvolvedo...
# 28      Há 1 mês  https://br.linkedin.com/jobs/view/desenvolvedo...
# 29    Há 2 meses  https://br.linkedin.com/jobs/view/programador-...
# 30   Há 1 semana  https://br.linkedin.com/jobs/view/desenvolvedo...
#
#    applications experience_level        job_type  \
# id
# 1          <=25       Assistente  Tempo integral
# 2          <=25       Assistente  Tempo integral
# 3          <=25       Assistente  Tempo integral
# 4          <=25       Assistente        Contrato
# 5          <=25       Assistente  Tempo integral
# 6          <=25       Assistente  Tempo integral
# 7          <=25     Pleno-sênior  Tempo integral
# 8          <=25    Não aplicável  Tempo integral
# 9          <=25       Assistente  Tempo integral
# 10          >25    Não aplicável  Tempo integral
# 11          >25       Assistente  Tempo integral
# 12          >25       Assistente  Tempo integral
# 13         <=25     Pleno-sênior  Tempo integral
# 14         <=25    Não aplicável  Tempo integral
# 15         <=25       Assistente  Tempo integral
# 16         <=25       Assistente  Tempo integral
# 17          >25    Não aplicável  Tempo integral
# 18          >25       Assistente  Tempo integral
# 19         <=25       Assistente  Tempo integral
# 20         <=25       Assistente  Tempo integral
# 21         <=25     Pleno-sênior  Tempo integral
# 22         <=25       Assistente  Tempo integral
# 23         <=25       Assistente  Tempo integral
# 24         <=25       Assistente  Tempo integral
# 25         <=25       Assistente  Tempo integral
# 26         <=25       Assistente  Tempo integral
# 27       Hidden       Assistente  Tempo integral
# 28       Hidden       Assistente        Contrato
# 29         <=25       Assistente  Tempo integral
# 30          >25     Pleno-sênior  Tempo integral
#
#                                      role  \
# id
# 1   Engenharia e Tecnologia da informação
# 2   Engenharia e Tecnologia da informação
# 3   Engenharia e Tecnologia da informação
# 4                Tecnologia da informação
# 5   Engenharia e Tecnologia da informação
# 6   Engenharia e Tecnologia da informação
# 7                Tecnologia da informação
# 8   Engenharia e Tecnologia da informação
# 9   Engenharia e Tecnologia da informação
# 10  Engenharia e Tecnologia da informação
# 11  Engenharia e Tecnologia da informação
# 12                       Recursos humanos
# 13  Engenharia e Tecnologia da informação
# 14  Engenharia e Tecnologia da informação
# 15  Engenharia e Tecnologia da informação
# 16  Engenharia e Tecnologia da informação
# 17               Tecnologia da informação
# 18  Engenharia e Tecnologia da informação
# 19  Engenharia e Tecnologia da informação
# 20  Engenharia e Tecnologia da informação
# 21               Tecnologia da informação
# 22  Engenharia e Tecnologia da informação
# 23  Engenharia e Tecnologia da informação
# 24  Engenharia e Tecnologia da informação
# 25  Engenharia e Tecnologia da informação
# 26  Engenharia e Tecnologia da informação
# 27  Engenharia e Tecnologia da informação
# 28               Tecnologia da informação
# 29  Engenharia e Tecnologia da informação
# 30  Engenharia e Tecnologia da informação
#
#                                               sectors  \
# id
# 1         Sociedades de fomento mercantil - factoring
# 2                   Tecnologia, Informação e Internet
# 3                   Tecnologia, Informação e Internet
# 4                      Serviços de gestão estratégica
# 5            Produtos de software de computação móvel
# 6            Produtos de software de computação móvel
# 7   Atividades dos serviços de tecnologia da infor...
# 8       Assessoria em relações públicas e comunicação
# 9                   Tecnologia, Informação e Internet
# 10  Atividades dos serviços de tecnologia da infor...
# 11  Atividades dos serviços de tecnologia da infor...
# 12  Atividades dos serviços de tecnologia da infor...
# 13                  Segurança de redes e computadores
# 14          Fornecimento e gestão de recursos humanos
# 15                                 Serviços de design
# 16                           Publicidade e propaganda
# 17                             Serviços de informação
# 18                             Publicação na Internet
# 19  Treinamento e suporte em tecnologia da informação
# 20                  Tecnologia, Informação e Internet
# 21  Atividades dos serviços de tecnologia da infor...
# 22                             Publicação na Internet
# 23                 Atividades de serviços financeiros
# 24    Atividades de consultoria em gestão empresarial
# 25        Sociedades de fomento mercantil - factoring
# 26                  Tecnologia, Informação e Internet
# 27  Atividades dos serviços de tecnologia da infor...
# 28                     Serviços de gestão estratégica
# 29           Produtos de software de computação móvel
# 30                             Publicação na Internet
#
#                                           description  \
# id
# 1   Manipular arquivos do servidor web. Criar scri...
# 2   Vagas para os times de tecnologia e desenvolvi...
# 3                                       Sem descrição
# 4   Olá Dev.Estamos com posições em andamento aqui...
# 5   Projetar, construir e otimizar interfaces dos ...
# 6                                       Sem descrição
# 7   Hey, é hora de você se juntar a nós para mostr...
# 8   Já pensou em fazer parte da empresa que está c...
# 9   Vaga 100% remota n.Empresa stoom, de campinas-...
# 10  Aqui você vai encontrar:Oportunidade de aprend...
# 11  Responsabilidades e AtividadesDesenvolvimento ...
# 12  DESCRIÇÃOA IOB não vê limites quando o assunto...
# 13  Se você é um Desenvolvedor Front-end talentoso...
# 14  Quais Serão As Suas ResponsabilidadesAtuar no ...
# 15  Description: Atribuições: Compreender e implem...
# 16  Job DescriptionVaga para nosso BANCO DE TALENT...
# 17  Company DescriptionSomos uma empresa global, l...
# 18  Requisitos Microserviços API's Firt API's Rest...
# 19  Capacitar-se para desempenhar as funções de ní...
# 20  Como desenvolvedor back-End senior, você será ...
# 21  DescriçãoVaga para Desenvolvedor Front EndEsta...
# 22  O que você vai fazer no seu dia a dia: Como ma...
# 23  Como é o ambiente de trabalho?A Travelex é hoj...
# 24  DescriptionVocê na DeloitteJá pensou atuar em ...
# 25  Manipular arquivos do servidor web. Criar scri...
# 26  Vagas para os times de tecnologia e desenvolvi...
# 27                                      Sem descrição
# 28  Olá Dev.Estamos com posições em andamento aqui...
# 29  Projetar, construir e otimizar interfaces dos ...
# 30  A GO IT Concept é uma start-up de tecnologia p...
#
#                                            requisitos  \
# id
# 1                                            SQL, PHP
# 2                                    Não especificado
# 3                                    Não especificado
# 4                                    Não especificado
# 5                                           WORDPRESS
# 6                                    Não especificado
# 7                         JAVA, SQL, NODE.JS, PHP, GO
# 8       CLOUD, REACT, AZURE, GRAPHQL, PYTHON, AWS, GO
# 9   JQUERY, JAVASCRIPT, REACT, BOOTSTRAP, HTML, FL...
# 10                          NOSQL, JAVA, GIT, ANGULAR
# 11  JAVA, RUBY, JAVASCRIPT, EXCEL, SQL, REACT, GIT...
# 12                 CLOUD, JAVA, DELPHI, C#, AWS, .NET
# 13   JAVASCRIPT, REACT, BOOTSTRAP, HTML, FLUTTER, CSS
# 14                                   AWS, PYTHON, GIT
# 15  LARAVEL, JAVASCRIPT, EXCEL, REACT, PHP, WORDPR...
# 16  CLOUD, JAVA, NODE.JS, JAVASCRIPT, REACT, VUE.J...
# 17                                             PYTHON
# 18                                  JAVA, GIT, SPRING
# 19   JAVA, SQL, JQUERY, SPRING, GIT, LINUX, HTML, CSS
# 20                                   Não especificado
# 21  JAVASCRIPT, REACT, GIT, BOOTSTRAP, ANGULAR, HT...
# 22                              HTML, REACT, GIT, CSS
# 23                                   NOSQL, JAVA, SQL
# 24                      HTML, CSS, JAVASCRIPT, VUE.JS
# 25                                           SQL, PHP
# 26                                   Não especificado
# 27                                   Não especificado
# 28                                   Não especificado
# 29                                          WORDPRESS
# 30                                                 GO
#
#                                                 lista
# id
# 1                                          [SQL, PHP]
# 2                                    Não especificado
# 3                                    Não especificado
# 4                                    Não especificado
# 5                                         [WORDPRESS]
# 6                                    Não especificado
# 7                       [JAVA, SQL, NODE.JS, PHP, GO]
# 8     [CLOUD, REACT, AZURE, GRAPHQL, PYTHON, AWS, GO]
# 9   [JQUERY, JAVASCRIPT, REACT, BOOTSTRAP, HTML, F...
# 10                        [NOSQL, JAVA, GIT, ANGULAR]
# 11  [JAVA, RUBY, JAVASCRIPT, EXCEL, SQL, REACT, GI...
# 12               [CLOUD, JAVA, DELPHI, C#, AWS, .NET]
# 13  [JAVASCRIPT, REACT, BOOTSTRAP, HTML, FLUTTER, ...
# 14                                 [AWS, PYTHON, GIT]
# 15  [LARAVEL, JAVASCRIPT, EXCEL, REACT, PHP, WORDP...
# 16  [CLOUD, JAVA, NODE.JS, JAVASCRIPT, REACT, VUE....
# 17                                           [PYTHON]
# 18                                [JAVA, GIT, SPRING]
# 19  [JAVA, SQL, JQUERY, SPRING, GIT, LINUX, HTML, ...
# 20                                   Não especificado
# 21  [JAVASCRIPT, REACT, GIT, BOOTSTRAP, ANGULAR, H...
# 22                            [HTML, REACT, GIT, CSS]
# 23                                 [NOSQL, JAVA, SQL]
# 24                    [HTML, CSS, JAVASCRIPT, VUE.JS]
# 25                                         [SQL, PHP]
# 26                                   Não especificado
# 27                                   Não especificado
# 28                                   Não especificado
# 29                                        [WORDPRESS]
# 30                                               [GO]

# %%
# export_test= dados_nao_nulos[dados_nao_nulos.requisitos=="SQL"]

# %%
# export_test.to_excel("exports_test.xlsx")
dados_nao_nulos[dados_nao_nulos.lista!='Não especificado']
# Out:
#                                                   title  \
# id
# 1                                   Desenvolvedor MYSQL
# 5                                       Programador Web
# 7                                    Back End Developer
# 8                        DESENVOLVEDOR REACT JR (VIBRA)
# 9                                         Desenvolvedor
# ...                                                 ...
# 1995       Desenvolvedor Back End Python Sênior - 18113
# 1997  DESENVOLVEDOR(A) BACK END - PLENO - Back-End |...
# 1998                          Desenvolvedor Java Sênior
# 1999                    Programador Golang Pleno/Sênior
# 2001                     Analista Programador C# Sênior
#
#                     location   time_opened  \
# id
# 1     Greater São Paulo Area    Há 3 meses
# 5     Greater São Paulo Area    Há 2 meses
# 7              São Paulo, SP  Há 2 semanas
# 8              São Paulo, SP   Há 1 semana
# 9     Greater São Paulo Area   Há 1 semana
# ...                      ...           ...
# 1995           São Paulo, SP    Há 2 meses
# 1997           São Paulo, SP     Há 2 dias
# 1998           São Paulo, SP   Há 1 semana
# 1999           São Paulo, SP   Há 1 semana
# 2001              Osasco, SP    Há 2 meses
#
#                                                    link applications  \
# id
# 1     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 5     https://br.linkedin.com/jobs/view/programador-...         <=25
# 7     https://br.linkedin.com/jobs/view/back-end-dev...         <=25
# 8     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 9     https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# ...                                                 ...          ...
# 1995  https://br.linkedin.com/jobs/view/desenvolvedo...       Hidden
# 1997  https://br.linkedin.com/jobs/view/desenvolvedo...         <=25
# 1998  https://br.linkedin.com/jobs/view/desenvolvedo...       Hidden
# 1999  https://br.linkedin.com/jobs/view/programador-...       Hidden
# 2001  https://br.linkedin.com/jobs/view/analista-pro...       Hidden
#
#      experience_level        job_type                                   role  \
# id
# 1          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 5          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 7        Pleno-sênior  Tempo integral               Tecnologia da informação
# 8       Não aplicável  Tempo integral  Engenharia e Tecnologia da informação
# 9          Assistente  Tempo integral  Engenharia e Tecnologia da informação
# ...               ...             ...                                    ...
# 1995     Pleno-sênior  Tempo integral               Tecnologia da informação
# 1997     Pleno-sênior  Tempo integral  Engenharia e Tecnologia da informação
# 1998       Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 1999       Assistente  Tempo integral  Engenharia e Tecnologia da informação
# 2001       Assistente  Tempo integral  Engenharia e Tecnologia da informação
#
#                                                 sectors  \
# id
# 1           Sociedades de fomento mercantil - factoring
# 5              Produtos de software de computação móvel
# 7     Atividades dos serviços de tecnologia da infor...
# 8         Assessoria em relações públicas e comunicação
# 9                     Tecnologia, Informação e Internet
# ...                                                 ...
# 1995                           Telecomunicações sem fio
# 1997                        Desenvolvimento de software
# 1998  Atividades dos serviços de tecnologia da infor...
# 1999  Atividades dos serviços de tecnologia da infor...
# 2001  Atividades dos serviços de tecnologia da infor...
#
#                                             description  \
# id
# 1     Manipular arquivos do servidor web. Criar scri...
# 5     Projetar, construir e otimizar interfaces dos ...
# 7     Hey, é hora de você se juntar a nós para mostr...
# 8     Já pensou em fazer parte da empresa que está c...
# 9     Vaga 100% remota n.Empresa stoom, de campinas-...
# ...                                                 ...
# 1995  Desenvolvedor Back End SR.Informação Important...
# 1997  HabilidadesLaravel, PHP, ReactJS, Vue.jsO que ...
# 1998                                      Sem descrição
# 1999                                      Sem descrição
# 2001                                      Sem descrição
#
#                                              requisitos  \
# id
# 1                                              SQL, PHP
# 5                                             WORDPRESS
# 7                           JAVA, SQL, NODE.JS, PHP, GO
# 8         CLOUD, REACT, AZURE, GRAPHQL, PYTHON, AWS, GO
# 9     JQUERY, JAVASCRIPT, REACT, BOOTSTRAP, HTML, FL...
# ...                                                 ...
# 1995                                   PYTHON, SQL, AWS
# 1997               LARAVEL, REACT, PHP, EXPRESS, VUE.JS
# 1998                                               JAVA
# 1999                                                 GO
# 2001                                                 C#
#
#                                                   lista
# id
# 1                                            [SQL, PHP]
# 5                                           [WORDPRESS]
# 7                         [JAVA, SQL, NODE.JS, PHP, GO]
# 8       [CLOUD, REACT, AZURE, GRAPHQL, PYTHON, AWS, GO]
# 9     [JQUERY, JAVASCRIPT, REACT, BOOTSTRAP, HTML, F...
# ...                                                 ...
# 1995                                 [PYTHON, SQL, AWS]
# 1997             [LARAVEL, REACT, PHP, EXPRESS, VUE.JS]
# 1998                                             [JAVA]
# 1999                                               [GO]
# 2001                                               [C#]
#
# [1718 rows x 12 columns]

# %%
df = dados_nao_nulos[dados_nao_nulos.lista!='Não especificado']

# Converter listas em strings simples
df['lista'] = df['lista'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# Explodir a coluna 'tecnologia'
df = df.assign(lista=df['lista'].str.split(', ')).explode('lista')

# Contar ocorrências de cada tecnologia
count_tecnologia = df['lista'].value_counts()

print(count_tecnologia.sum())
# Out:
# 8327
# C:\Users\pcozz\AppData\Local\Temp\ipykernel_15276\2456253688.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lista'] = df['lista'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# %%
df_temp=dados_nao_nulos[dados_nao_nulos.requisitos!='Não especificado']

# %%
contagem_tecnologias = df.lista.value_counts()
cores = []
for _ in range(len(contagem_tecnologias)):
    cor = (random.random(), random.random(), random.random())
    cores.append(cor)
    
plt.figure(figsize=(8, 18))

bars = plt.barh(contagem_tecnologias.index, contagem_tecnologias, color=cores)
plt.title("Tecnologias mais pedidas em vagas com os requisitos especificados")

for bar, valor in zip(bars, contagem_tecnologias):
    plt.text(bar.get_width()+20, bar.get_y() + bar.get_height()/2, f'{valor}---> Pedido em ({round((valor / (len(df_temp))*100),2)}%) das vagas', ha='left', va='center')
plt.xlim(right=max(contagem_tecnologias) * 2.3)
plt.show()

# %%
# dados_nao_nulos = dados_nao_nulos.drop(columns=['lista'])

# %%
# dados_nao_nulos[dados_nao_nulos['requisitos'].str.contains("GIT")].loc[10].description

# %%
regex_str_posicao = 'Estagiário|Estagiario|Junior|Júnior|JR|Nivel 1|Nivel I|Nível 1|Nível I|Pleno/Sênior|Senior|Sênior|SR|Pleno|Tech Lead|Tech-lead|Diretor|Coordenador|Gerente'

# %%
#Buscar posicao no titulo da vaga
def busca_posicao(title):
    tecnologia =''
    if re.findall(regex_str_posicao, title,re.IGNORECASE) != []:
        tecnologia = re.findall(regex_str_posicao, title,re.IGNORECASE)[0].upper().replace(" ","").replace("-","")
    else: 
        tecnologia = "Não especificado"
        
    return tecnologia 

def busca_posicao_detalhe(title):
    tecnologia = ''
    tecnologias_encontradas = re.findall(regex_str_posicao, title, re.IGNORECASE)
    
    if tecnologias_encontradas:
        # Conta a frequência das tecnologias encontradas
        contador = Counter(tecnologias_encontradas)
        
        # Escolhe a tecnologia mais frequente
        tecnologia_mais_frequente = contador.most_common(1)[0][0].upper().replace(" ","").replace("-","")
        
        tecnologia = tecnologia_mais_frequente
    else: 
        tecnologia = "Não especificado"
        
    return tecnologia

def busca_posicao_descricao(title):
    tecnologia = ''
    tecnologias_encontradas = re.findall(regex_str_posicao, title, re.IGNORECASE)
    
    if tecnologias_encontradas:
        # Conta a frequência das tecnologias encontradas
        contador = Counter(tecnologias_encontradas)
        
        # Escolhe a tecnologia mais frequente
        tecnologia_mais_frequente = contador.most_common(1)[0][0].upper().replace(" ","").replace("-","")
        
        tecnologia = tecnologia_mais_frequente
    else: 
        tecnologia = "Não especificado"
        
    return tecnologia

# %%
dados_nao_nulos['posicao'] = dados_nao_nulos.title.apply(lambda x: busca_posicao(x))

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao']=='Não especificado','posicao']=dados_nao_nulos.experience_level.apply(lambda x: busca_posicao_detalhe(x))

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao']=='Não especificado','posicao']=dados_nao_nulos.description.apply(lambda x: busca_posicao_descricao(x))

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['SR', 'SENIOR']),'posicao']="SÊNIOR"

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['JR']),'posicao']="JUNIOR"

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['JÚNIOR']),'posicao']="JUNIOR"

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['NÍVELI','NÍVEL1']),'posicao']="JUNIOR"

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['TECH LEAD,TECH-LEAD']),'posicao']="TECH-LEAD"

# %%
dados_nao_nulos.loc[dados_nao_nulos['posicao'].isin(['ESTAGIÁRIO']),'posicao']="ESTAGIARIO"

# %%
contagem_posicoes = dados_nao_nulos.posicao.value_counts()
cores = []
for _ in range(len(contagem_posicoes)):
    cor = (random.random(), random.random(), random.random())
    cores.append(cor)
    
plt.figure(figsize=(10, 8))

bars = plt.barh(contagem_posicoes.index, contagem_posicoes, color=cores)
plt.title("Posicões em vagas")

for bar, valor in zip(bars, contagem_posicoes):
    plt.text(bar.get_width()+20, bar.get_y() + bar.get_height()/2, f'({round((valor / (len(dados_nao_nulos.posicao)))*100,2)}%)', ha='left', va='center')
plt.xlim(right=max(contagem_posicoes) * 1.2)
plt.show()

# %%
dados_grafico2=dados_nao_nulos[(dados_nao_nulos.posicao!='Não especificado') & (dados_nao_nulos.requisitos!='Não especificado')]

# %%
dados_explodidos = dados_grafico2.assign(requisitos=dados_grafico2['requisitos'].str.split(', ')).explode('requisitos')

# Em seguida, agrupe pelos valores da coluna 'posicao' e conte os valores da coluna 'requisitos' após a explosão
contagem_requisitos = dados_explodidos.groupby('posicao')['requisitos'].value_counts()

contagem_requisitos2 = dados_explodidos.groupby(['posicao', 'requisitos']).size()

# Use value_counts() e depois nlargest() para obter os 10 principais valores
top10_por_posicao = contagem_requisitos2.groupby(level=0).nlargest(10).reset_index(level=1, drop=True)

# Agora você tem a contagem de cada requisito para cada posição

# %%
contagem_requisitos.value_counts()
# Out:
# count
# 1     43
# 2     24
# 3     21
# 5     13
# 4      9
#       ..
# 10     1
# 35     1
# 24     1
# 37     1
# 75     1
# Name: count, Length: 66, dtype: int64

# %%
dados = top10_por_posicao

posicoes = sorted(set(posicao for posicao, _ in dados.keys()))
tecnologias = sorted(set(tecnologia for _, tecnologia in dados.keys()))

# Criar uma matriz de contagem de tecnologias para todas as posições
matriz_contagem = np.zeros((len(posicoes), len(tecnologias)))

# Preencher a matriz com as contagens reais
for i, posicao in enumerate(posicoes):
    for j, tecnologia in enumerate(tecnologias):
        matriz_contagem[i, j] = dados.get((posicao, tecnologia), 0)

# Criar o gráfico de barras empilhadas
plt.figure(figsize=(12, 8))

bottom = np.zeros(len(tecnologias))
for i, posicao in enumerate(posicoes):
    plt.bar(tecnologias, matriz_contagem[i], label=posicao, bottom=bottom)
    bottom += matriz_contagem[i]

plt.xlabel('Tecnologia')
plt.ylabel('Contagem')
plt.title('Contagem de Tecnologias por Posição')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
dados_junior = contagem_requisitos.loc['JUNIOR']

# Selecionar apenas os 10 primeiros requisitos mais pedidos
dados_junior_top10 = dados_junior.head(20)

# Criar o gráfico de barras
plt.figure(figsize=(12, 8))
bars=plt.bar(dados_junior_top10.index, dados_junior_top10.values, color='skyblue')

for bar, valor in zip(bars, dados_junior_top10.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'({round((valor/(dados_junior_top10.values.sum())*100),2)})%', ha='center', va='bottom')

plt.xlabel('Requisitos')
plt.ylabel('Contagem')
plt.title('Top 20 Requisitos mais Pedidos para a Posição JUNIOR')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Selecionar apenas os 10 primeiros requisitos mais pedidos
dados_pleno = contagem_requisitos.loc['PLENO']
dados_pleno_top10 = dados_pleno.head(20)

# Criar o gráfico de barras
plt.figure(figsize=(12, 8))
bars = plt.bar(dados_pleno_top10.index, dados_pleno_top10.values, color='orange')

for bar, valor in zip(bars, dados_pleno_top10.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'({round((valor/(dados_pleno_top10.values.sum())*100),2)})%', ha='center', va='bottom')

plt.xlabel('Requisitos')
plt.ylabel('Contagem')
plt.title('Top 20 Requisitos mais Pedidos para a Posição PLENO')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
dados_senior = contagem_requisitos.loc['SÊNIOR']

# Selecionar apenas os 10 primeiros requisitos mais pedidos
dados_junior_top10 = dados_senior.head(20)

# Criar o gráfico de barras
plt.figure(figsize=(12, 8))
plt.bar(dados_junior_top10.index, dados_junior_top10.values, color='brown')
plt.xlabel('Requisitos')
plt.ylabel('Contagem')
plt.title('Top 20 Requisitos mais Pedidos para a Posição SENIOR')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
dados_nao_nulos.isnull().sum()
# Out:
# title               0
# location            0
# time_opened         0
# link                0
# applications        0
# experience_level    0
# job_type            0
# role                0
# sectors             0
# description         0
# requisitos          0
# lista               0
# posicao             0
# dtype: int64
