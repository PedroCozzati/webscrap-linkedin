# %%
import pandas as pd

# %%
dados = pd.read_csv("linkedin_jobs.csv")

# %%
dados.isnull().sum()
# Out:
# title                 0
# company               0
# location              0
# time_opened           0
# link                  0
# applications        167
# experience_level     18
# job_type             18
# role                 18
# sectors              19
# description          18
# dtype: int64

# %%
empregos_validos =dados[dados['location'].str.contains("São Paulo")]

# %%
empregos_validos = empregos_validos[~empregos_validos['experience_level'].str.contains("Pleno-sênior",na=False)]

# %%
empregos_validos
# Out:
#                                            title  \
# 0                            Desenvolvedor MYSQL
# 1                                  Desenvolvedor
# 2                     Desenvolvedor(a) Front-End
# 3                    Desenvolvedor full stack jr
# 4                                Programador Web
# ..                                           ...
# 618  Programador C# Pleno - Visual Studio Expert
# 620   Desenvolvedor(a) Back-end JAVA EE (Remoto)
# 626                              Analista Devops
# 628                              Analista Devops
# 629                        Desenvolvedor .Net PL
#
#                                   company                location  \
# 0              Casa do Crédito S.A. - SCM  Greater São Paulo Area
# 1                          Hiper Software  Greater São Paulo Area
# 2          Brivia | The Creative Smartech           São Paulo, SP
# 3                                   Devio  Greater São Paulo Area
# ...
